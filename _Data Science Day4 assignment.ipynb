# %% [markdown]
# # Question 1.How to import  Pe versandas and check thion?

# %%
import pandas as pd
pd.show_versions()
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.8.3.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# machine          : AMD64
# processor        : Intel64 Family 6 Model 78 Stepping 3, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_India.1252
#
# pandas           : 1.0.5
# numpy            : 1.18.5
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.1.1
# setuptools       : 49.2.0.post20200714
# Cython           : 0.29.21
# pytest           : 5.4.3
# hypothesis       : None
# sphinx           : 3.1.2
# ...

# %% [markdown]
# # Question-2 How To create a series from a numpy array?

# %%
import pandas as pd 
import numpy as np 
data = np.array(['a', 'b', 'c', 'd', 'e']) 
  
# creating series 
s = pd.Series(data) 
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %% [markdown]
# # Question-3 How to convert the index of series into a column of a dataframe?

# %%
import pandas as pd
#Creating the dataframe df 
df = pd.DataFrame({'Roll Number': ['20CSE29', '20CSE49', '20CSE36', '20CSE44'], 
                   'Name': ['Amelia', 'Sam', 'Dean', 'Jessica'], 
                   'Marks In Percentage': [97, 90, 70, 82], 
                   'Grade': ['A', 'A', 'C', 'B'], 
                   'Subject': ['Physics', 'Physics', 'Physics', 'Physics']}) 
  
# Printing the dataframe 
df
# Out:
#   Roll Number     Name  Marks In Percentage Grade  Subject
# 0     20CSE29   Amelia                   97     A  Physics
# 1     20CSE49      Sam                   90     A  Physics
# 2     20CSE36     Dean                   70     C  Physics
# 3     20CSE44  Jessica                   82     B  Physics

# %% [markdown]
# # Question-4 Write down the code to list aii the datasets available in seaborn library.load the 'mpg' dataset.

# %%
import seaborn as sns

mpg=sns.load_dataset('mpg')

print(mpg)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
#  # Question-5 Which country origin cars are a part of this dataset?

# %%
import seaborn as sns
import pandas as pd
mpg=sns.load_dataset('mpg')

# creating a dataframe
df = pd.DataFrame(mpg)

# Displaying the country origin from where cars belong
df.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %% [markdown]
# # Question - 6:Extract the part of the dataframe which contains cars belonging to 'usa'¶

# %%
# importing seaborn
import seaborn as sns
# importing pandas with alias name
import pandas as pd

# loading the dataset from seaborn
mpg=sns.load_dataset('mpg')

# creating a dataframe
df = pd.DataFrame(mpg)

# Displaying the part from dataframe where cars belong to "usa"
df[df['origin'].str.contains("usa")]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# ...
